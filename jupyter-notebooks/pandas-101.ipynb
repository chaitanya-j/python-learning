# %% [markdown]
# # A Program in which we have used most of the functions in Pandas

# %%
import pandas as pd

# %% [markdown]
# ### Loading the first CSV

# %%
df = pd.read_csv('lptp_info.csv')

# %%
df
# Out:
#     id         hostname      ip-address criticality  freq locationnnn
# 0   10  test-machine-01   10.20.20.2100        High    20        Pune
# 1  11a       test-vm-03  10.200.200.150      Medium    90         NaN
# 2   13          prod-01   63.123.254.11        High    35      London

# %% [markdown]
# ### Now here we are converting the dict - 'dic' into a dataframe!

# %%
dic = {'Name':['Tom', 'nick', 'krish', 'jack'],
        'Age':[20, 21, 19, 18]
      }

# %%
dframe = pd.DataFrame(dic)

# %%
dframe
# Out:
#     Name  Age
# 0    Tom   20
# 1   nick   21
# 2  krish   19
# 3   jack   18

# %%
dframe.columns = ['NAME','AGE']

# %%
dframe
# Out:
#      NME  AGE
# 0    Tom   20
# 1   nick   21
# 2  krish   19
# 3   jack   18

# %% [markdown]
# #### Now here we are totally replacing the column names

# %%
dframe.replace(columns={'A','B'})
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-9-fed7293243dd> in <module>
# ----> 1 dframe.replace(columns={'A','B'})
#
# TypeError: replace() got an unexpected keyword argument 'columns'

# %% [markdown]
# ### Now here we are loading the stack-overflow CSV

# %%
dataf = pd.read_csv('survey_results_public.csv')

# %%
dataf
# Out:
#        Respondent                                         MainBranch Hobbyist  \
# 0               1                     I am a developer by profession      Yes
# 1               2                     I am a developer by profession       No
# 2               3                        I code primarily as a hobby      Yes
# 3               4                     I am a developer by profession      Yes
# 4               5  I used to be a developer by profession, but no...      Yes
# ...           ...                                                ...      ...
# 64456       64858                                                NaN      Yes
# 64457       64867                                                NaN      Yes
# 64458       64898                                                NaN      Yes
# 64459       64925                                                NaN      Yes
# 64460       65112                                                NaN      Yes
#
# ...

# %%
from matplotlib import pyplot as plt

# %%
# %matplotlib inline

# %%
dataf['Country'].value_counts()
# Out:
# United States                         12469
# India                                  8403
# United Kingdom                         3896
# Germany                                3890
# Canada                                 2191
#                                       ...
# Saint Lucia                               1
# Mali                                      1
# Nauru                                     1
# Kiribati                                  1
# Micronesia, Federated States of...        1
# Name: Country, Length: 183, dtype: int64

# %%
f = (dataf['OrgSize'] == '2 to 9 employees')

dataf[f]['YearsCodePro']

#plt.hist(dataf['Age1stCode'], bins=10)
#plt.show()
# Out:
# 0                      27
# 9                       4
# 11                      7
# 12                     20
# 45                      4
#                ...
# 64011    Less than 1 year
# 64068                  16
# 64115                  10
# 64142                   2
# 64153                   3
# Name: YearsCodePro, Length: 4409, dtype: object

# %%
dataf.columns
# Out:
# Index(['Respondent', 'MainBranch', 'Hobbyist', 'Age', 'Age1stCode', 'CompFreq',
#        'CompTotal', 'ConvertedComp', 'Country', 'CurrencyDesc',
#        'CurrencySymbol', 'DatabaseDesireNextYear', 'DatabaseWorkedWith',
#        'DevType', 'EdLevel', 'Employment', 'Ethnicity', 'Gender', 'JobFactors',
#        'JobSat', 'JobSeek', 'LanguageDesireNextYear', 'LanguageWorkedWith',
#        'MiscTechDesireNextYear', 'MiscTechWorkedWith',
#        'NEWCollabToolsDesireNextYear', 'NEWCollabToolsWorkedWith', 'NEWDevOps',
#        'NEWDevOpsImpt', 'NEWEdImpt', 'NEWJobHunt', 'NEWJobHuntResearch',
#        'NEWLearn', 'NEWOffTopic', 'NEWOnboardGood', 'NEWOtherComms',
#        'NEWOvertime', 'NEWPurchaseResearch', 'NEWPurpleLink', 'NEWSOSites',
#        'NEWStuck', 'OpSys', 'OrgSize', 'PlatformDesireNextYear',
#        'PlatformWorkedWith', 'PurchaseWhat', 'Sexuality', 'SOAccount',
#        'SOComm', 'SOPartFreq', 'SOVisitFreq', 'SurveyEase', 'SurveyLength',
# ...

# %% [markdown]
# ### Now here we are filtering :
# ### We are searching the country name 'United States' in the 'Country' collumn. If it is there then it will show True in the collumn or else false

# %%
filt = (dataf['Country'] == 'United States')

# %%
filt
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4         True
#          ...
# 64456     True
# 64457    False
# 64458    False
# 64459    False
# 64460    False
# Name: Country, Length: 64461, dtype: bool

# %% [markdown]
# ### Now let's take the head and the tail of the CSV : 'survey_results_public'

# %%
dataf.head(3)
# Out:
#    Respondent                      MainBranch Hobbyist  Age Age1stCode  \
# 0           1  I am a developer by profession      Yes  NaN         13
# 1           2  I am a developer by profession       No  NaN         19
# 2           3     I code primarily as a hobby      Yes  NaN         15
#
#   CompFreq  CompTotal  ConvertedComp             Country    CurrencyDesc  ...  \
# 0  Monthly        NaN            NaN             Germany   European Euro  ...
# 1      NaN        NaN            NaN      United Kingdom  Pound sterling  ...
# 2      NaN        NaN            NaN  Russian Federation             NaN  ...
#
#                    SurveyEase           SurveyLength Trans  \
# 0  Neither easy nor difficult  Appropriate in length    No
# 1                         NaN                    NaN   NaN
# 2  Neither easy nor difficult  Appropriate in length   NaN
#
#                                       UndergradMajor WebframeDesireNextYear  \
# ...

# %%
dataf.tail(3)
# Out:
#        Respondent MainBranch Hobbyist  Age Age1stCode CompFreq  CompTotal  \
# 64458       64898        NaN      Yes  NaN        NaN      NaN        NaN
# 64459       64925        NaN      Yes  NaN        NaN      NaN        NaN
# 64460       65112        NaN      Yes  NaN        NaN      NaN        NaN
#
#        ConvertedComp   Country CurrencyDesc  ... SurveyEase SurveyLength  \
# 64458            NaN  Viet Nam          NaN  ...        NaN          NaN
# 64459            NaN    Poland          NaN  ...        NaN          NaN
# 64460            NaN     Spain          NaN  ...        NaN          NaN
#
#       Trans                                     UndergradMajor  \
# 64458   NaN                                                NaN
# 64459   NaN                                                NaN
# 64460   NaN  Computer science, computer engineering, or sof...
#
#             WebframeDesireNextYear                      WebframeWorkedWith  \
# ...

# %% [markdown]
# ### Now here we are loading the collumns from index no : 2 - 5

# %%
dataf.loc[2:5]
# Out:
#    Respondent                                         MainBranch Hobbyist  \
# 2           3                        I code primarily as a hobby      Yes
# 3           4                     I am a developer by profession      Yes
# 4           5  I used to be a developer by profession, but no...      Yes
# 5           6                     I am a developer by profession       No
#
#     Age Age1stCode CompFreq  CompTotal  ConvertedComp             Country  \
# 2   NaN         15      NaN        NaN            NaN  Russian Federation
# 3  25.0         18      NaN        NaN            NaN             Albania
# 4  31.0         16      NaN        NaN            NaN       United States
# 5   NaN         14      NaN        NaN            NaN             Germany
#
#     CurrencyDesc  ...                  SurveyEase           SurveyLength  \
# 2            NaN  ...  Neither easy nor difficult  Appropriate in length
# 3   Albanian lek  ...                         NaN                    NaN
# ...
